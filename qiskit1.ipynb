# %%
from qiskit import QuantumCircuit, Aer, assemble    
from qiskit.visualization import plot_histogram

# %%
n = 8
qc = QuantumCircuit(n,n)

# %%
for j in range(n):
    qc.measure(j,j)

# %%
qc.draw()
# Out:
#      ┌─┐
# q_0: ┤M├─────────────────────
#      └╥┘┌─┐
# q_1: ─╫─┤M├──────────────────
#       ║ └╥┘┌─┐
# q_2: ─╫──╫─┤M├───────────────
#       ║  ║ └╥┘┌─┐
# q_3: ─╫──╫──╫─┤M├────────────
#       ║  ║  ║ └╥┘┌─┐
# q_4: ─╫──╫──╫──╫─┤M├─────────
#       ║  ║  ║  ║ └╥┘┌─┐
# q_5: ─╫──╫──╫──╫──╫─┤M├──────
#       ║  ║  ║  ║  ║ └╥┘┌─┐
# q_6: ─╫──╫──╫──╫──╫──╫─┤M├───
#       ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# q_7: ─╫──╫──╫──╫──╫──╫──╫─┤M├
#       ║  ║  ║  ║  ║  ║  ║ └╥┘
# c_0: ═╩══╬══╬══╬══╬══╬══╬══╬═
#          ║  ║  ║  ║  ║  ║  ║
# c_1: ════╩══╬══╬══╬══╬══╬══╬═
#             ║  ║  ║  ║  ║  ║
# c_2: ═══════╩══╬══╬══╬══╬══╬═
#                ║  ║  ║  ║  ║
# c_3: ══════════╩══╬══╬══╬══╬═
#                   ║  ║  ║  ║
# c_4: ═════════════╩══╬══╬══╬═
#                      ║  ║  ║
# c_5: ════════════════╩══╬══╬═
#                         ║  ║
# c_6: ═══════════════════╩══╬═
#                            ║
# c_7: ══════════════════════╩═

# %%
qc.draw('mpl')

# %%
qc.draw('latex')
# Out:
# <PIL.Image.Image image mode=RGB size=896x1259 at 0x7FE564396FA0>

# %%
sim = Aer.get_backend('qasm_simulator')
qoj = assemble(qc)

# %%
result = sim.run(qoj).result()
counts = result.get_counts()

# %%
plot_histogram(counts)
